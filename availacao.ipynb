# %%
import pandas as pd
import numpy as np
import matplotlib as mat

df = pd.read_csv('jogadores_22.csv')
df
# Out:
#        sofifa_id          short_name                            long_name  \
# 0         158023            L. Messi       Lionel Andrés Messi Cuccittini
# 1         188545      R. Lewandowski                   Robert Lewandowski
# 2          20801   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3         190871           Neymar Jr        Neymar da Silva Santos Júnior
# 4         192985        K. De Bruyne                      Kevin De Bruyne
# ...          ...                 ...                                  ...
# 19234     261962           Song Defu                                  宋德福
# 19235     262040           C. Porter                      Caoimhin Porter
# 19236     262760            N. Logue              Nathan Logue-Cunningham
# 19237     262820           L. Rudden                          Luke Rudden
# 19238     264540  E. Lalchhanchhuaha              Emanuel Lalchhanchhuaha
#
#        overall  potential    value_eur  wage_eur  age        dob  height_cm  \
# 0           93         93   78000000.0  320000.0   34  6/24/1987        170
# 1           92         92  119500000.0  270000.0   32  8/21/1988        185
# 2           91         91   45000000.0  270000.0   36   2/5/1985        187
# 3           91         91  129000000.0  270000.0   29   2/5/1992        175
# 4           91         91  125500000.0  350000.0   30  6/28/1991        181
# ...        ...        ...          ...       ...  ...        ...        ...
# 19234       47         52      70000.0    1000.0   22   1/2/1999        180
# 19235       47         59     110000.0     500.0   19  3/18/2002        175
# 19236       47         55     100000.0     500.0   21   2/7/2000        178
# 19237       47         60     110000.0     500.0   19  4/23/2002        173
# 19238       47         60     110000.0     500.0   19   2/6/2002        167
#
#        ...  mentality_composure  defending_marking_awareness  \
# 0      ...                   96                           20
# 1      ...                   88                           35
# 2      ...                   95                           24
# 3      ...                   93                           35
# 4      ...                   89                           68
# ...    ...                  ...                          ...
# 19234  ...                   37                           38
# 19235  ...                   47                           37
# 19236  ...                   36                           38
# 19237  ...                   47                           10
# 19238  ...                   36                           33
#
#       defending_standing_tackle defending_sliding_tackle  goalkeeping_diving  \
# 0                            35                       24                   6
# 1                            42                       19                  15
# 2                            32                       24                   7
# 3                            32                       29                   9
# 4                            65                       53                  15
# ...                         ...                      ...                 ...
# 19234                        43                       48                   6
# 19235                        44                       47                  11
# 19236                        44                       48                   8
# 19237                        14                       11                   7
# 19238                        31                       37                   8
#
#       goalkeeping_handling  goalkeeping_kicking goalkeeping_positioning  \
# 0                       11                   15                      14
# 1                        6                   12                       8
# 2                       11                   15                      14
# 3                        9                   15                      15
# 4                       13                    5                      10
# ...                    ...                  ...                     ...
# 19234                   10                    5                      15
# 19235                   12                    6                       8
# 19236                    6                    7                      10
# 19237                   10                    7                      14
# 19238                   13                   13                       9
#
#       goalkeeping_reflexes  goalkeeping_speed
# 0                        8                NaN
# 1                       10                NaN
# 2                       11                NaN
# 3                       11                NaN
# 4                       13                NaN
# ...                    ...                ...
# 19234                   13                NaN
# 19235                   10                NaN
# 19236                    6                NaN
# 19237                   15                NaN
# 19238                   14                NaN
#
# [19239 rows x 72 columns]

# %% [markdown]
# # quantos jogadores estão na base de dados

# %%
len(df)
# Out:
# 19239

# %%
df['age'] = pd.to_numeric(df['age'].mean())
df['age']
# Out:
# 0        25.210822
# 1        25.210822
# 2        25.210822
# 3        25.210822
# 4        25.210822
#            ...
# 19234    25.210822
# 19235    25.210822
# 19236    25.210822
# 19237    25.210822
# 19238    25.210822
# Name: age, Length: 19239, dtype: float64

# %% [markdown]
# ### Qual a media de idade dos jogadores

# %% [markdown]
# # quais seleções com a maior média de idade dos jogadores

# %%
# Garantir que a coluna 'age' seja numérica (em caso de erro de tipo)
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# Criar o DataFrame 'selecao' com a coluna de idade e a seleção
selecao = pd.DataFrame({
    'age': df['age'],
    'selecao': df['nationality_name']
})

# Agrupar por 'selecao' e calcular a média da idade
media = selecao.groupby('selecao')['age'].mean()

# Ordenar as seleções pela média de idade, da maior para a menor
top_10_selecoes = media.sort_values(ascending=False).head(10)

# Exibir o resultado
# print(top_10_selecoes)
print(df['age'].unique())

print(selecao['selecao'].value_counts())
# Out:
# [25.21082177]
# selecao
# England             1719
# Germany             1214
# Spain               1086
# France               980
# Argentina            960
#                     ...
# Ethiopia               1
# Papua New Guinea       1
# Kyrgyzstan             1
# Guam                   1
# Indonesia              1
# Name: count, Length: 163, dtype: int64

# %%
df.columns
# Out:
# Index(['sofifa_id', 'short_name', 'long_name', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg',
#        'club_team_id', 'club_name', 'league_name', 'league_level',
#        'club_position', 'club_jersey_number', 'club_loaned_from',
#        'club_joined', 'club_contract_valid_until', 'nationality_id',
#        'nationality_name', 'nation_team_id', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'work_rate', 'body_type',
#        'real_face', 'release_clause_eur', 'pace', 'shooting', 'passing',
#        'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed'],
#       dtype='object')

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

selecao = pd.DataFrame({
    'age': df['age'],
    'selecao': df['nationality_name']
})

media = selecao.groupby('selecao')['age'].mean()
print(media.head())

top_3_selecoes = media.sort_values(ascending=False).head(3)
print(top_3_selecoes)
# Out:
# selecao
# Afghanistan    23.000000
# Albania        25.413043
# Algeria        26.784314
# Andorra        31.000000
# Angola         24.588235
# Name: age, dtype: float64
# selecao
# Korea DPR    39.0
# Eritrea      36.0
# Ethiopia     35.0
# Name: age, dtype: float64

# %%
jogadores_por_selecao = selecao.groupby('selecao').size()
jogadores_por_selecao.head(5)
# Out:
# selecao
# Afghanistan     1
# Albania        46
# Algeria        51
# Andorra         1
# Angola         17
# dtype: int64

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

selecao = pd.DataFrame({
    'age': df['age'],
    'selecao': df['nationality_name']
})

media = selecao.groupby('selecao')['age'].mean()
print(media.head())

top_3_selecoes = media.sort_values(ascending=False).head(3)
print(top_3_selecoes)
# Out:
# selecao
# Afghanistan    23.000000
# Albania        25.413043
# Algeria        26.784314
# Andorra        31.000000
# Angola         24.588235
# Name: age, dtype: float64
# selecao
# Korea DPR    39.0
# Eritrea      36.0
# Ethiopia     35.0
# Name: age, dtype: float64

# %%
br = selecao[selecao['selecao'] == 'Brazil']

# Calcular a média de idade para os jogadores da Albânia
media_idade_albania = br['age'].mean()
media_idade_albania
# Out:
# 25.21082176828317

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('jogadores_22.csv')
selecoes_desejadas = ['Argentina', 'Brasil', 'Alemanha', 'França']
dados_filtrados = df[df['nationality_name'].isin(selecoes_desejadas)]
altura_argentina = dados_filtrados[dados_filtrados['nationality_name'] == 'Argentina']['height_cm']
altura_brasil = dados_filtrados[dados_filtrados['nationality_name'] == 'Brasil']['height_cm']
altura_alemanha = dados_filtrados[dados_filtrados['nationality_name'] == 'Alemanha']['height_cm']
altura_franca = dados_filtrados[dados_filtrados['nationality_name'] == 'França']['height_cm']
plt.figure(figsize=(10, 5))
plt.boxplot([altura_argentina, altura_brasil, altura_alemanha, altura_franca], 
            labels=['Argentina', 'Brasil', 'Alemanha', 'França'])
plt.title('Comparativo das Alturas dos Jogadores das Seleções: Argentina, Brasil, Alemanha e França')
plt.xlabel('Seleção')
plt.ylabel('Altura (cm)')

plt.show()
# Out:
# /tmp/ipykernel_10919/2059999080.py:19: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([altura_argentina, altura_brasil, altura_alemanha, altura_franca],

# %%
import pandas as pd

# Carregar os dados do CSV
df = pd.read_csv('jogadores_22.csv')

# Encontrar o jogador mais velho
jogador_mais_velho = df.loc[df['age'].idxmax()]

# Exibir o nome do jogador e a nacionalidade
nome_jogador = jogador_mais_velho['long_name']
idade_jogador = jogador_mais_velho['age']
nacionalidade_jogador = jogador_mais_velho['nationality_name']

print(f'O jogador mais velho é {nome_jogador}, com {idade_jogador} anos, da seleção {nacionalidade_jogador}.')
# Out:
# O jogador mais velho é 三浦 知良, com 54 anos, da seleção Japan.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('jogadores_22.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['height_cm'], df['weight_kg'], alpha=0.5, c='blue', edgecolors='w', s=60)
plt.title('Dispersão de Altura vs Peso dos Jogadores', fontsize=14)
plt.xlabel('Altura (cm)', fontsize=12)
plt.ylabel('Peso (kg)', fontsize=12)
plt.grid(True)
plt.show()
